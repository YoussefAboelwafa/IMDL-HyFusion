# %%
# !pip install ultralytics yacs pretty_errors

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git checkout traning
# !git pull origin traning
# !git push -u origin traning

# %%
# prompt: remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/YoussefAboelwafa/IMDL-HyFusion.git/'

from google.colab import drive
# !pip install ultralytics yacs pretty_errors
drive.mount('/content/drive')

# Use a Personal Access Token (PAT) instead of password
# 1. Generate a PAT in your GitHub settings (Developer settings -> Personal access tokens)
# 2.  Replace <YOUR_PAT> with your actual token.  Do NOT share your PAT!

# %%
# !cd /content/drive/MyDrive/IMDL && git push https://ahmedsamirsaid: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@github.com/ahmedsamirsaid/IMDL.git
# Out:
# remote: Write access to repository not granted.
# fatal: unable to access 'https://github.com/ahmedsamirsaid/IMDL.git/': The requested URL returned error: 403

# %%
# !cd /content/drive/MyDrive/IMDL && git remote set-url origin  https://ahmedsamirsaid:01123069839sssal292002@github.com/YoussefAboelwafa/IMDL-HyFusion.git

# %%
# !cd /content/drive/MyDrive/IMDL && git push --set-upstream origin traning
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/YoussefAboelwafa/IMDL-HyFusion.git/'

# %%
# !python /content/drive/MyDrive/IMDL/ec_train.py --exp /content/drive/MyDrive/IMDL/experiments/ec_example.yaml --gpu 0
# Out:
# 2025-03-07 15:05:58.522316: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741359958.576042    3547 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741359958.586506    3547 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-07 15:05:58.607626: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
